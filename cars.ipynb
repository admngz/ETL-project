# %%
import pandas as pd

# %%
# load datasets
make_df =  pd.read_csv('Make.csv')
auction_df = pd.read_csv('USA_cars_datasets.csv')
sales_df = pd.read_csv('Car_sales.csv')
msrp_df = pd.read_csv('data.csv')

# %%
# drop na values
auction_df.dropna(how='all', inplace=True)
# Out:
#       Unnamed: 0  price      brand    model  year   title_status   mileage  \
# 0              0   6300     toyota  cruiser  2008  clean vehicle  274117.0
# 1              1   2899       ford       se  2011  clean vehicle  190552.0
# 2              2   5350      dodge      mpv  2018  clean vehicle   39590.0
# 3              3  25000       ford     door  2014  clean vehicle   64146.0
# 4              4  27700  chevrolet     1500  2018  clean vehicle    6654.0
# ...          ...    ...        ...      ...   ...            ...       ...
# 2494        2494   7800     nissan    versa  2019  clean vehicle   23609.0
# 2495        2495   9200     nissan    versa  2018  clean vehicle   34553.0
# 2496        2496   9200     nissan    versa  2018  clean vehicle   31594.0
# 2497        2497   9200     nissan    versa  2018  clean vehicle   32557.0
# 2498        2498   9200     nissan    versa  2018  clean vehicle   31371.0
#
#        color                  vin        lot       state country  \
# ...

# %% [markdown]
# # Auction

# %%
# make_df cleaning steps
auction_df.country.unique()

# drop columns with country=Canada
auction_df2 = auction_df[['Unnamed: 0', 'price', 'brand', 'year', 'color', 'state', 'country', 'mileage']].copy()

# %%
index = auction_df2[auction_df2['year'] > 2017].index
auction_df2.drop(index, inplace=True)

# %%
#confirm years are between 1993-2017
auction_df2.year.unique()
# Out:
# array([2008, 2011, 2014, 2010, 2017, 2009, 2013, 2015, 2016, 1973, 2003,
#        2002, 2000, 2001, 2005, 2012, 2006, 2007, 1998, 2004, 1994, 1997,
#        1996, 1999, 1984, 1995, 1993], dtype=int64)

# %%
# remove canada from dataframe
index = auction_df2[auction_df2['country'] == 'canada'].index
auction_df2.drop(index, inplace=True)

# %%
# noted that country had a space before the usa
auction_df2.country.unique()
# Out:
# array([' usa'], dtype=object)

# %%
# remove space
auction_df2.country = auction_df2.country.str.replace(' ', '')

# %%
auction_df2.country.unique()
# Out:
# array(['usa'], dtype=object)

# %%
auction_clean = auction_df2.rename(columns={'Unnamed: 0': 'id'})

# %%
# export to clean .csv
auction_clean.to_csv(r'auction_clean.csv', index=False)

# %%
auction_clean
# Out:
#         id  price      brand  year   color       state country   mileage
# 0        0   6300     toyota  2008   black  new jersey     usa  274117.0
# 1        1   2899       ford  2011  silver   tennessee     usa  190552.0
# 3        3  25000       ford  2014    blue    virginia     usa   64146.0
# 6        6   7300  chevrolet  2010   black     georgia     usa  149050.0
# 7        7  13350        gmc  2017    gray  california     usa   23525.0
# ...    ...    ...        ...   ...     ...         ...     ...       ...
# 2444  2444  15200     nissan  2016  orange    illinois     usa   59640.0
# 2445  2445   1950     nissan  2015    blue  california     usa   83975.0
# 2446  2446  13400     nissan  2016   black    illinois     usa   46178.0
# 2453  2453   1500     nissan  2013   black    maryland     usa   98384.0
# 2470  2470   3700     nissan  2015  silver    illinois     usa   75858.0
#
# [1164 rows x 8 columns]

# %% [markdown]
# # sales

# %%
sales_df
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
# drop NaN values
sales_df = sales_df.dropna()

# %%
sales_clean = sales_df.rename(columns={'__year_resale_value': 'resale_value'})

# %%
sales_clean.reset_index(drop=True, inplace=True)

# %%
sales_clean['Manufacturer'] = sales_clean['Manufacturer'].str.lower()
sales_clean['Model'] = sales_clean['Model'].str.lower()

# %%
sales_clean
# Out:
#     Manufacturer    Model  Sales_in_thousands  resale_value Vehicle_type  \
# 0          acura  integra              16.919        16.360    Passenger
# 1          acura       tl              39.384        19.875    Passenger
# 2          acura       rl               8.588        29.725    Passenger
# 3           audi       a4              20.397        22.255    Passenger
# 4           audi       a6              18.780        23.555    Passenger
# ..           ...      ...                 ...           ...          ...
# 112   volkswagen     golf               9.761        11.425    Passenger
# 113   volkswagen    jetta              83.721        13.240    Passenger
# 114   volkswagen   passat              51.102        16.725    Passenger
# 115   volkswagen   cabrio               9.569        16.575    Passenger
# 116   volkswagen      gti               5.596        13.760    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# ...

# %%
# drop last two columns 
sales_clean

# %%
sales_clean = sales_clean.drop(['Latest_Launch', 'Power_perf_factor', 'Vehicle_type'], axis=1)

# %%
sales_clean
# Out:
#     Manufacturer    Model  Sales_in_thousands  resale_value  \
# 0          acura  integra              16.919        16.360
# 1          acura       tl              39.384        19.875
# 2          acura       rl               8.588        29.725
# 3           audi       a4              20.397        22.255
# 4           audi       a6              18.780        23.555
# ..           ...      ...                 ...           ...
# 112   volkswagen     golf               9.761        11.425
# 113   volkswagen    jetta              83.721        13.240
# 114   volkswagen   passat              51.102        16.725
# 115   volkswagen   cabrio               9.569        16.575
# 116   volkswagen      gti               5.596        13.760
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0                 21.50          1.8       140.0      101.2   67.3   172.4
# 1                 28.40          3.2       225.0      108.1   70.3   192.9
# ...

# %%
# export to .csv
sales_clean.to_csv('sales_clean.csv', index=True)

# %% [markdown]
# # MSRP

# %%
msrp_df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          bmw  1 series m  2011     premium unleaded (required)      335.0
# 1          bmw    1 series  2011     premium unleaded (required)      300.0
# 2          bmw    1 series  2011     premium unleaded (required)      300.0
# 3          bmw    1 series  2011     premium unleaded (required)      230.0
# 4          bmw    1 series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    acura         zdx  2012     premium unleaded (required)      300.0
# 11910    acura         zdx  2012     premium unleaded (required)      300.0
# 11911    acura         zdx  2012     premium unleaded (required)      300.0
# 11912    acura         zdx  2013  premium unleaded (recommended)      300.0
# 11913  lincoln      zephyr  2006                regular unleaded      221.0
#
# ...

# %%
# drop NaN values
msrp_df = msrp_df.dropna()

# %%
msrp_df['Make'] = msrp_df['Make'].str.lower()
msrp_df['Model'] = msrp_df['Model'].str.lower()
msrp_df['Transmission Type'] = msrp_df['Transmission Type'].str.lower()

# %%
msrp_df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  bmw  1 series m  2011  premium unleaded (required)      335.0
# 1  bmw    1 series  2011  premium unleaded (required)      300.0
# 2  bmw    1 series  2011  premium unleaded (required)      300.0
# 3  bmw    1 series  2011  premium unleaded (required)      230.0
# 4  bmw    1 series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            manual  rear wheel drive              2.0
# 1               6.0            manual  rear wheel drive              2.0
# 2               6.0            manual  rear wheel drive              2.0
# 3               6.0            manual  rear wheel drive              2.0
# 4               6.0            manual  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
msrp_df.to_csv('msrp_clean.csv', index=True)
